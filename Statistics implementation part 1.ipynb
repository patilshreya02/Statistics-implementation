# %% [markdown]
# ### Measures of central tendency
# mean,median,mode

# %%
ages=[23,3,4,55,5,56,44,32]

# %%
import pandas as pd
import numpy as np
np.mean(ages)
# Out:
# 27.75

# %%
np.median(ages)
# Out:
# 27.5

# %%
ages1=[23,24,32,12,43,45,67,45,32,56,32,120]  #outlier (100)
np.mean(ages1)
# Out:
# 44.25

# %%
np.median(ages1) #not to much effect of outlier on median but not in case of mean
# Out:
# 37.5

# %% [markdown]
# #### Another way to find mean ,median

# %%
import statistics
statistics.mean(ages)
# Out:
# 27.75

# %%
statistics.median(ages)
# Out:
# 27.5

# %%
statistics.mode(ages)#we use mode for finding categorical values
# Out:
# 23

# %%
#outlier
import seaborn as sns
sns.boxplot(ages1)
# Out:
# C:\Users\patil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# ### 5 number summary

# %%
np.percentile(ages1,[25,75,99])
# Out:
# array([ 30.  ,  47.75, 114.17])

# %%
#values under lower fence and upper fence are not outliers
#IQR (difference between 25-75 percentile)
q1,q3=np.percentile(ages1,[25,75])
IQR=q3-q1
lf=q1-1.5*(IQR)
uf=q3+1.5*(IQR)
lf
# Out:
# 3.375

# %%
uf
# Out:
# 74.375

# %% [markdown]
# ### Measure of dispersion
# Variance
#
# Standard deviation

# %%
statistics.variance(ages1)
# Out:
# 795.2954545454545

# %%
np.var(ages1,axis=0)
# Out:
# 729.0208333333334

# %% [markdown]
# # Difference
# stats.var- it takes sample variance formula(xi/n-1)
#
# np.var- it takes population formula(xi/n)

# %%
#population var in stats
statistics.pvariance(ages1)
# Out:
# 729.0208333333334

# %%
import math
sd=math.sqrt(statistics.pvariance(ages1))
sd
# Out:
# 27.000385799712813

# %%
ages1=[23,24,32,12,43,45,67,45,32,56,32,120]  #outlier (100)
mean=np.mean(ages1)
mean
# Out:
# 44.25

# %%
x=ages1-mean
x
# Out:
# array([-21.25, -20.25, -12.25, -32.25,  -1.25,   0.75,  22.75,   0.75,
#        -12.25,  11.75, -12.25,  75.75])

# %%
sample=x**2
sample
# Out:
# array([4.5156250e+02, 4.1006250e+02, 1.5006250e+02, 1.0400625e+03,
#        1.5625000e+00, 5.6250000e-01, 5.1756250e+02, 5.6250000e-01,
#        1.5006250e+02, 1.3806250e+02, 1.5006250e+02, 5.7380625e+03])

# %%
sum1=sum(sample)
sum1
# Out:
# 8748.25

# %%
var=sum1/11
var
# Out:
# 795.2954545454545

# %%
sd=math.sqrt(var)
sd
# Out:
# 28.2009832194811

# %%
import matplotlib.pyplot as plt
# Generate data points for the x-axis (range of possible values)
x = np.linspace(mean - 3 * sd, mean + 3 * sd, 100)

# Calculate the corresponding y-values using the probability density function of the normal distribution
y = (1 / (sd * np.sqrt(2 * np.pi))) * np.exp(-(x - mean)**2 / (2 * sd**2))

# Plot the bell curve
plt.plot(x, y)

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Probability Density')
plt.title('Bell Curve (Normal Distribution)')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

ages1 = [23, 24, 32, 12, 43, 45, 67, 45, 32, 56, 32, 120]

# Plot histogram
plt.hist(ages1, bins=10, edgecolor='black')

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')  #frequency refers to the number of data points that fall within each bin or interval of the histogram.
plt.title('Histogram of Ages')

# Show the plot
plt.show()
sns.histplot(ages1,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# #### kde-kernal density estimate
# If kde=true(it create smoothing)

# %%
import seaborn as sns

ages1 = [23, 24, 32, 12, 43, 45, 67, 45, 32, 56, 32, 120]

# Create density plot
sns.kdeplot(ages1)

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Density Plot of Ages')

# Show the plot
plt.show()
